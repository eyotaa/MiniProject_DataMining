# %% [markdown]
# <a href="https://colab.research.google.com/github/eyotaa/MiniProject_DataMining/blob/main/datamining(5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Analisis terhadap Bank Rakyat Indonesia Stock Historical Price**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image
import numpy as np
import plotly.express as px

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# Analisis data historis harga saham BBRI.JK dapat memberikan wawasan yang berharga tentang pergerakan harga saham di masa lalu dan kinerja perusahaan. Informasi ini dapat digunakan untuk memprediksi pergerakan harga saham di masa depan, mengevaluasi kinerja BBRI.JK, dan mengidentifikasi peluang investasi.

# %% [markdown]
# ##**Business Objective**

# %% [markdown]
# Business Objective
# Memahami pergerakan harga saham BBRI.JK di masa lalu: Dengan menganalisis data historis, kita dapat mengidentifikasi pola dan tren yang dapat membantu memprediksi pergerakan harga saham di masa depan.<br>
# A. Mengevaluasi kinerja BBRI.JK:<br>
# Analisis data historis dapat membantu kita menilai kinerja BBRI.JK dibandingkan dengan perusahaan lain di sektor perbankan dan pasar secara keseluruhan.<br>
# B. Mengidentifikasi peluang investasi:<br>
# Dengan memahami pergerakan harga saham BBRI.JK dan kinerja perusahaan, kita dapat mengidentifikasi peluang investasi yang potensial.

# %% [markdown]
# ##**Assess Situation**

# %% [markdown]
# Dengan kapitalisasi pasar lebih dari Rp 1.000 triliun, BBRI.JK adalah salah satu bank terbesar di Indonesia. Bank ini memiliki sejarah yang panjang dan dihormati, dan selama bertahun-tahun, telah menunjukkan kinerja yang konsisten dan menguntungkan. Namun, BBRI.JK tidak terlepas dari ketidakpastian pasar, seperti halnya perusahaan lainnya. Dalam beberapa tahun terakhir, harga saham BBRI.JK telah mengalami fluktuasi yang signifikan, yang dipengaruhi oleh sejumlah variabel, termasuk kebijakan pemerintah, kinerja industri perbankan, dan kondisi ekonomi makro.

# %% [markdown]
# ##**Data Mining Goals**

# %% [markdown]
# Tujuan penambangan dataset dari harga saham BBRI.JK sebelumnya adalah untuk:
#
# A. Mengidentifikasi pola dan tren:<br>
# menemukan pola dan tren dalam data yang tidak mudah terlihat dengan mata telanjang dengan menggunakan teknik data mining.<br>
# B. Membangun model prediktif:<br>
#  menggunakan model prediktif untuk memprediksi bagaimana harga saham BBRI.JK akan bergerak di masa depan sehingga dapat digunakan untuk mengembangkan strategi investasi.

# %% [markdown]
# ##**Project Plan**

# %% [markdown]
# Rencana proyek untuk analisis data historis harga saham BBRI.JK adalah sebagai Berikut:<br>
# A. Pengumpulan data:<br>
# Data harga saham BBRI.JK sebelumnya akan dikumpulkan dari berbagai sumber, seperti Bursa Efek Indonesia, Yahoo! Finansial, dan Google! Finansial.<br>
# B. Pembersihan data:<br>
# Untuk menghilangkan nilai yang hilang dan tidak akurat, data yang dikumpulkan akan dibersihkan.<br>
# C.Analisis data:<br>
# Berbagai teknik statistik dan data mining akan digunakan untuk menganalisis data yang dibersihkan.<br>
# D. Konstruksi model prediktif:<br>
# Model prediktif akan dibangun untuk memprediksi bagaimana harga saham BBRI.JK akan bergerak di masa depan.<br>
# E. Pengembangan strategi investasi:<br>
# Berdasarkan analisis data sebelumnya, strategi investasi akan dikembangkan.

# %% [markdown]
# #**DATA UNDERSTANDING**

# %% [markdown]
# ##**Collect Initial Data**

# %% [markdown]
# sumber data ini didapat dari situs kaggel https://www.kaggle.com/datasets/caesarmario/bank-rakyat-indonesia-stock-historical-price
# data ini adalah riwayat harga saham bbri dari 2019 hingga 2024
# terdapat 3 buah data yang merupakan data harian,mingguan,bulanan dari 2019 hingga 2024

# %%
df = pd.read_csv("https://raw.githubusercontent.com/eyotaa/MiniProject_DataMining/main/checkpoin%201/BBRI.JK.csv")

# %% [markdown]
# ####Daily

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     2019-01-01  3327.215332  3327.215332  3327.215332  3327.215332
# 1     2019-01-02  3281.761475  3309.033691  3263.580078  3281.761475
# 2     2019-01-03  3254.489258  3309.033691  3254.489258  3290.852295
# 3     2019-01-04  3290.852295  3327.215332  3281.761475  3327.215332
# 4     2019-01-07  3363.578369  3372.668945  3327.215332  3327.215332
# ...          ...          ...          ...          ...          ...
# 1267  2024-02-23  6125.000000  6175.000000  6050.000000  6125.000000
# 1268  2024-02-26  6100.000000  6200.000000  6075.000000  6175.000000
# 1269  2024-02-27  6125.000000  6200.000000  6125.000000  6125.000000
# 1270  2024-02-28  6100.000000  6225.000000  6100.000000  6225.000000
# 1271  2024-02-29  6150.000000  6200.000000  6125.000000  6125.000000
#
#         Adj Close     Volume
# 0     2692.883301          0
# 1     2656.094971   82441033
# 2     2663.452881  102805905
# ...

# %% [markdown]
# ##**Describe Data**

# %% [markdown]
# ####Informasi Dasar

# %%
print("informasi dasar terkait dataset:")
print("jumlah baris pada data Daily"),
print(len(df)),
print("jumlah kolom pada data Daily"),
print(len(df.columns))
# Out:
# informasi dasar terkait dataset:
# jumlah baris pada data Daily
# 1272
# jumlah kolom pada data Daily
# 7

# %% [markdown]
# pada masing masing data di atas memiliki jumlah bris 1272 pada data daily, 270 untuk weekly, 63 untuk montly dan untuk kolom nya berjumah sama yaitu 7 yang meliputi (open, high, low, close, adj close dan volume)

# %% [markdown]
# ####Informasi Lanjutan

# %%
print("informasi lanjutan terkait dataaset ini"),
df.info()
#Ketikan kode di sini, untuk menampilkan informasi lengkap dari dataset kalian
# Out:
# informasi lanjutan terkait dataaset ini
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1272 non-null   object
#  1   Open       1272 non-null   float64
#  2   High       1272 non-null   float64
#  3   Low        1272 non-null   float64
#  4   Close      1272 non-null   float64
#  5   Adj Close  1272 non-null   float64
#  6   Volume     1272 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.7+ KB

# %% [markdown]
# Penjelasan Open, High, Low, Close, Adj Close, dan Volume pada Saham
# Berikut adalah penjelasan mengenai istilah-istilah yang Anda sebutkan:
# 1. date (tanggal)object
# <br> funsi date adaalah diamana tanggal terjadinya saham dibuka dan ditutup
# 1. Open (Harga Pembukaan)float
# <br>Harga pembukaan adalah harga pertama yang diperdagangkan pada suatu hari untuk suatu saham. Harga ini ditentukan berdasarkan keseimbangan antara pembeli dan penjual pada saat pasar dibuka.
#
# 1. High (Harga Tertinggi)float
# <br>Harga tertinggi adalah harga tertinggi yang dicapai suatu saham selama perdagangan pada suatu hari.
#
# 1. Low (Harga Terendah)float
# <br>Harga terendah adalah harga terendah yang dicapai suatu saham selama perdagangan pada suatu hari.
#
# 1. Close (Harga Penutupan)float
# <br>Harga penutupan adalah harga terakhir yang diperdagangkan pada suatu hari untuk suatu saham. Harga ini menentukan nilai akhir suatu saham pada hari tersebut.
#
# 1. Adj Close (Harga Penutupan yang Disesuaikan)float
# <br>Harga penutupan yang disesuaikan adalah harga penutupan yang telah diubah untuk memperhitungkan peristiwa korporasi seperti pemecahan saham dan dividen. Harga ini digunakan untuk melacak kinerja saham secara lebih akurat dari waktu ke waktu.
#
# 1. Volume (Volume Perdagangan)int
# <br>Volume perdagangan adalah jumlah saham yang diperdagangkan pada suatu hari. Volume tinggi menunjukkan bahwa banyak investor yang tertarik pada saham tersebut, sedangkan volume rendah menunjukkan sebaliknya.

# %% [markdown]
# ####Informasi Statistik Deskriptif

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1272.000000  1272.000000  1272.000000  1272.000000  1272.000000
# mean   4162.454362  4205.367449  4114.033954  4158.173429  3764.062767
# std     809.132909   809.675030   811.801597   812.946000   942.411240
# min    2045.419189  2063.600830  1963.602417  1972.693237  1717.858765
# 25%    3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 50%    4109.510010  4147.691406  4070.000000  4109.510010  3568.853760
# 75%    4650.000000  4682.500000  4600.000000  4640.000000  4311.354980
# max    6325.000000  6375.000000  6225.000000  6300.000000  6300.000000
#
#              Volume
# count  1.272000e+03
# mean   1.565900e+08
# std    9.958485e+07
# min    0.000000e+00
# 25%    9.579682e+07
# 50%    1.314421e+08
# 75%    1.844417e+08
# max    9.598846e+08

# %% [markdown]
# Berikut adalah penjelasan untuk setiap kolom:
#
# 1. **Open (Pembukaan):**
#    - **Rata-rata:** 4162.45
#    - **Standar Deviasi:** 809.13
#    - **Minimum:** 2045.42
#    - **25%**: 3645.39
#    - **50%** (Median): 4109.51
#    - **75%**: 4650.00
#    - **Maksimum:** 6325.00
#    - **Keterangan:** Harga pembukaan rata-rata selama periode waktu tertentu adalah sekitar 4162.45, dengan fluktuasi standar sebesar 809.13. Harga pembukaan terendah mencapai 2045.42, sementara tertinggi mencapai 6325.00.
#
# 2. **High (Tertinggi):**
#    - **Rata-rata:** 4205.37
#    - **Standar Deviasi:** 809.68
#    - **Minimum:** 2063.60
#    - **25%:** 3699.94
#    - **50% (Median):** 4147.69
#    - **75%:** 4682.50
#    - **Maksimum:** 6375.00
#    - **Keterangan:** Harga tertinggi rata-rata selama periode waktu tersebut adalah sekitar 4205.37. Harga tertinggi dalam periode tersebut mencapai 6375.00, sedangkan harga terendah adalah 2063.60.
#
# 3. **Low (Terendah):**
#    - **Rata-rata:** 4114.03
#    - **Standar Deviasi:** 811.80
#    - **Minimum:** 1963.60
#    - **25%:** 3599.94
#    - **50% (Median):** 4070.00
#    - **75%:** 4600.00
#    - **Maksimum:** 6225.00
#    - **Keterangan:** Harga terendah rata-rata selama periode waktu tersebut adalah sekitar 4114.03. Harga terendah dalam periode tersebut mencapai 1963.60, sedangkan harga tertinggi adalah 6225.00.
#
# 4. **Close (Penutupan):**
#    - **Rata-rata:** 4158.17
#    - **Standar Deviasi:** 812.95
#    - **Minimum:** 1972.69
#    - **Maksimum:** 6300.00
#    - **Keterangan:** Harga penutupan rata-rata selama periode waktu tersebut adalah sekitar 4158.17. Harga penutupan terendah mencapai 1972.69, sementara tertinggi adalah 6300.00.
#
# 5. **Adj Close (Penutupan Disesuaikan):**
#    - **Rata-rata:** 3764.06
#    - **Standar Deviasi:** 942.41
#    - **Minimum:** 1717.86
#    - **25%:** 3644.04
#    - **50% (Median):** 4109.51
#    - **75%:** 4640.00
#    - **Maksimum:** 6300.00
#    - **Keterangan:** Harga penutupan disesuaikan rata-rata selama periode waktu tersebut adalah sekitar 3764.06. Harga penutupan disesuaikan terendah mencapai 1717.86, sementara tertinggi adalah 6300.00.
#
# 6. **Volume:**
#    - **Rata-rata:** 1.565900e+08 (156,590,000)
#    - **Standar Deviasi:** 9.958485e+07 (99,584,850)
#    - **Minimum:** 0
#    - **25%:** 9.579682e+07 (95,796,820)
#    - **50% (Median):** 1.314421e+08 (131,442,100)
#    - **75%:** 1.844417e+08 (184,441,700)
#    - **Maksimum:** 9.598846e+08 (959,884,600)
#    - **Keterangan:** Volume perdagangan rata-rata selama periode tersebut adalah sekitar 156,590,000. Volume perdagangan terendah adalah 0 (karna padda awal Saham IPO biasanya belum tercatat berapa lot telah dibeli lalu di hari berikutnya baru tercatat total lot yang sudah dimiliki investor), sementara tertinggi mencapai 959,884,600.

# %% [markdown]
# ##**Exploratory Data Analysis**

# %% [markdown]
# ####candlestick chart

# %%
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])




fig.update_layout(title='Candlestick Chart',
                  xaxis_title='Date',
                  yaxis_title='Stock Price (IDR)',
                  xaxis_rangeslider_visible=False,
                  template='plotly_dark')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. Tren dan Fluktuasi:
# Dapat dilihat dari visualisasi Time Series bahwa volume perdagangan saham BBRI mengalami fluktuasi yang signifikan dari waktu ke waktu. bullish and bearish pada grafik dapat mengindikasikan periode dengan volume tinggi atau rendah.
# 1. Pola dan Perubahan:
# Analisis histogram distribusi volume dapat memberikan wawasan tentang pola atau perubahan dalam volume perdagangan. Jika distribusi memiliki beberapa puncak, mungkin ada pola tertentu yang perlu dianalisis lebih lanjut.

# %%
# display(Image(filename='/content/stock-market-basics-candlestick-patterns.png'))

# %% [markdown]
# 1. Bagian Utama: Body (Badan) Candlestick<br>
# Badan candlestick mewakili rentang antara harga pembukaan (Open) dan harga penutupan (Close) pada periode tertentu. Jika harga penutupan lebih tinggi daripada harga pembukaan, maka badan candlestick akan diwarnai (biasanya) dengan warna putih atau hijau, menunjukkan sentimen positif. Sebaliknya, jika harga penutupan lebih rendah daripada harga pembukaan, badan candlestick akan diwarnai dengan warna hitam atau merah, menunjukkan sentimen negatif.<br>
#
# 1. Garis-garis atau Sumbu: Shadow atau Wick (Sumbu Atas dan Sumbu Bawah)<br>
# Sumbu atas menunjukkan harga tertinggi (High) yang dicapai selama periode tersebut.
# Sumbu bawah menunjukkan harga terendah (Low) yang dicapai selama periode tersebut.<br>
#
# 1. Panjang Badan Candlestick:<br>
# Panjang badan candlestick memberikan indikasi tentang seberapa besar pergerakan harga pada periode tersebut. Candlestick dengan badan panjang menunjukkan pergerakan harga yang signifikan, sedangkan candlestick dengan badan pendek menunjukkan pergerakan harga yang lebih kecil.<br>
#
# 1. Pattern dan Formasi Candlestick:<br>Pola dan formasi candlestick tertentu, seperti "doji", "engulfing", atau "hammer", dapat memberikan petunjuk tentang potensi perubahan dalam tren atau pembalikan arah harga.<br>
# 1. Tren:<br>
# Pada umumnya, jika candlestick-candlestick berturut-turut menunjukkan badan yang semakin tinggi (uptrend) atau semakin rendah (downtrend), ini bisa memberikan indikasi tentang kekuatan tren yang sedang berlangsung.

# %% [markdown]
# ####Korelasi

# %%
# Korelasi antar variabel
correlation_matrix = df.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Korelasi Antar Variabel')
plt.show()
# Out:
# <ipython-input-9-2345c0cd3f3b>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# 1. Harga Saham dengan Volume Perdagangan:<BR>
# Jika terdapat korelasi positif yang signifikan, artinya ada kecenderungan bahwa ketika harga saham naik, volume perdagangan juga meningkat, dan sebaliknya.<BR>
# 1. Harga Saham dengan Perubahan Persentase:<BR>
# Korelasi positif yang signifikan mungkin menunjukkan bahwa perubahan harga saham berkorelasi dengan perubahan persentase, yang dapat memberikan wawasan tentang volatilitas pasar.<BR>
# 1. Volume Perdagangan dengan Perubahan Persentase:<BR>
# Jika terdapat korelasi positif, hal tersebut dapat menunjukkan bahwa volume perdagangan meningkat saat terjadi perubahan persentase yang besar, yang mungkin terkait dengan aktivitas pasar yang lebih tinggi.<BR>
# 1. Variabel Lainnya:<BR>
# Korelasi antar variabel lainnya juga dapat memberikan wawasan tentang hubungan-hubungan tertentu di dalam dataset. Sebagai contoh, jika ada variabel lain yang memiliki korelasi tinggi dengan harga saham, hal tersebut dapat dijadikan fokus untuk analisis lebih lanjut.

# %% [markdown]
# #####perbandingan volume tahunan saham BBRI

# %%
# Konversi kolom 'Date' ke tipe data datetime
df['Date'] = pd.to_datetime(df['Date'])

# Ekstraksi tahun dan bulan dari kolom 'Date'
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month_name()

# Filter data untuk tahun-tahun yang diminta
selected_years = [2019, 2020, 2021, 2022, 2023, 2024]
df_selected_years = df[df['Year'].isin(selected_years)]

# Membuat candlestick chart per bulan untuk setiap tahun
for year in selected_years:
    df_year = df_selected_years[df_selected_years['Year'] == year]

    fig = go.Figure(data=[go.Candlestick(x=df_year['Date'],
                                         open=df_year['Open'],
                                         high=df_year['High'],
                                         low=df_year['Low'],
                                         close=df_year['Close'])])

    fig.update_layout(title=f'Candlestick Chart Saham BBRI Tahun {year}',
                      xaxis_title='Tanggal',
                      yaxis_title='Harga Saham (IDR)',
                      xaxis_rangeslider_visible=False,
                      template='plotly_dark')

    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Konversi kolom 'Date' ke tipe data datetime
df['Date'] = pd.to_datetime(df['Date'])
# Filter data untuk tahun-tahun yang diminta
selected_years = [2019, 2020, 2021, 2022, 2023, 2024]
df_selected_years = df[df['Year'].isin(selected_years)]

# Grouping berdasarkan tahun dan bulan, menghitung total volume
volume_per_month = df_selected_years.groupby(['Year', 'Month'])['Volume'].sum()

# Membuat diagram pie untuk setiap tahun
for year in selected_years:
    volume_per_year = volume_per_month.loc[year]

    plt.figure(figsize=(8, 8))
    plt.pie(volume_per_year, labels=volume_per_year.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
    plt.title(f'Perbandingan Volume Saham BBRI Bulanan Tahun {year}')
    plt.show()

# %% [markdown]
# Perbandingan Volume per Tahun:<br>
# **Volume BBRI menunjukkan tren naik dari tahun 2019 hingga 2024.** Tahun 2024 memiliki volume tertinggi, diikuti oleh tahun 2023 dan 2022.<br>
# **Fluktuasi volume antar bulan dalam setiap tahun cukup signifikan.** Kenaikan dan penurunan volume terjadi di berbagai bulan, dan tidak ada pola yang konsisten.
#
# Perbandingan Volume per Bulan:<br>
# **Secara umum, volume BBRI lebih tinggi di bulan-bulan akhir tahun** (Desember, November, Oktober) dibandingkan dengan bulan-bulan awal tahun. Hal ini mungkin terkait dengan aktivitas investor menjelang akhir tahun.<br>
#
# **Beberapa bulan menunjukkan lonjakan volume yang signifikan, seperti pada bulan Desember 2023 dan November 2024**. Hal ini mungkin disebabkan oleh peristiwa atau berita tertentu yang mempengaruhi pasar saham..

# %% [markdown]
# untuk menghapus fitur yang dibuat pada visualisasi diatas

# %%
df = df.drop(columns=['Year', 'Month'])
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2019-01-01  3327.215332  3327.215332  3327.215332  3327.215332  2692.883301
# 1 2019-01-02  3281.761475  3309.033691  3263.580078  3281.761475  2656.094971
# 2 2019-01-03  3254.489258  3309.033691  3254.489258  3290.852295  2663.452881
# 3 2019-01-04  3290.852295  3327.215332  3281.761475  3327.215332  2692.883301
# 4 2019-01-07  3363.578369  3372.668945  3327.215332  3327.215332  2692.883301
#
#       Volume
# 0          0
# 1   82441033
# 2  102805905
# 3  125907734
# 4   82106628

# %% [markdown]
# ##**Verify Data Quality**

# %% [markdown]
# ####Missing Values

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# Dari tabel diatas, terlihat jika semua kolom memiliki nilai null ratio yang sama yaitu 0.0. Jika Null Ratio adalah 0.0, itu berarti tidak ada data yang hilang atau kosong dalam kolom tersebut. Artinya, setiap baris dalam kolom memiliki nilai yang valid atau terisi. karna data set yang saya gunakan adalah dataset histori saham jadi kecil kemungkinan nya memiliki kekosongan di salah satu baris dalam kolom

# %% [markdown]
# ####Outliers Values

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom      Persentase Outliers
# Open                  0.471698
# High                  1.100629
# Low                   0.707547
# Close                 0.707547
# Adj Close             0.864780
# Volume                6.289308

# %% [markdown]
# 1. Open:
# <br>Persentase Outliers: Persentase nilai outliers dalam kolom 'Open'.
# <br>Interpretasi: Persentase outliers ini memberikan informasi tentang seberapa banyak nilai di kolom 'Open' berada di luar kisaran yang dianggap normal.<br>
# 1. High:
# <br>Persentase Outliers: Persentase nilai outliers dalam kolom 'High'.
# <br>Interpretasi: Persentase outliers di 'High' memberikan gambaran tentang seberapa jauh nilai tertinggi (High) melebihi kisaran yang dianggap normal.<br>
# 1. Low:
# <br>Persentase Outliers: Persentase nilai outliers dalam kolom 'Low'.
# <br>Interpretasi: Persentase outliers di 'Low' menunjukkan seberapa banyak nilai terendah (Low) berada di luar rentang yang dianggap normal.<br>
# 1. Close:
# <br>Persentase Outliers: Persentase nilai outliers dalam kolom 'Close'.
# <br>Interpretasi: Persentase outliers pada 'Close' memberikan gambaran tentang seberapa jauh nilai penutupan (Close) berada di luar rentang yang dianggap normal.<br>
# 1. Adj Close:
# <br>Persentase Outliers: Persentase nilai outliers dalam kolom 'Adj Close'.<br>Interpretasi: Persentase outliers pada 'Adj Close' menunjukkan seberapa banyak nilai penutupan yang disesuaikan (Adj Close) berada di luar rentang yang dianggap normal.<br>
# 1. Volume:
# <br>Persentase Outliers: Persentase nilai outliers dalam kolom 'Volume'.
# <br>Interpretasi: Persentase outliers pada 'Volume' memberikan informasi tentang seberapa banyak volume perdagangan berada di luar rentang yang dianggap normal.

# %% [markdown]
# ####Duplicated Values

# %%
# Cek apakah ada duplikat
if df.duplicated().any():
    print("Ada duplikat dalam DataFrame.")
else:
    print("Tidak ada duplikat dalam DataFrame.")
# Out:
# Tidak ada duplikat dalam DataFrame.

# %% [markdown]
# Dataset tidak memiliki duplikat jika setiap barisnya unik, artinya tidak ada baris yang sama persis dengan baris lainnya.

# %% [markdown]
# ####Inconsistent Values / Noise (Optional)

# %%
# Menampilkan informasi umum tentang dataset
print("Informasi Dataset Sebelum Pembersihan:")
print(df.info())

# Mendeteksi nilai-nilai yang mungkin inkonsisten
inconsistent_values = df[df['Low'] > df['High']]

# Menampilkan data yang mengandung inconsistent values
print("\nData dengan Inconsistent Values:")
print(inconsistent_values)

# Mengatasi inconsistent values dengan menukar nilai High dan Low jika Low > High
df.loc[inconsistent_values.index, ['Low', 'High']] = df.loc[inconsistent_values.index, ['High', 'Low']].values

# Menampilkan informasi umum setelah pembersihan
print("\nInformasi Dataset Setelah Pembersihan:")
print(df.info())
# Out:
# Informasi Dataset Sebelum Pembersihan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1272 non-null   datetime64[ns]
#  1   Open       1272 non-null   float64
#  2   High       1272 non-null   float64
#  3   Low        1272 non-null   float64
#  4   Close      1272 non-null   float64
#  5   Adj Close  1272 non-null   float64
#  6   Volume     1272 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.7 KB
# None
#
# Data dengan Inconsistent Values:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []
#
# Informasi Dataset Setelah Pembersihan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1272 entries, 0 to 1271
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %% [markdown]
# 1. Informasi Dataset Sebelum Pembersihan:
# <br>Dengan menggunakan metode info(), mendapatkan informasi umum tentang dataset, termasuk jumlah baris, kolom, dan tipe data masing-masing kolom.
# 1. Data dengan Inconsistent Values:
# <br>mencari baris-baris di mana nilai 'Low' (harga terendah) lebih tinggi dari nilai 'High' (harga tertinggi). Ini menunjukkan bahwa ada inkonsistensi dalam data, karena harga terendah seharusnya tidak lebih tinggi dari harga tertinggi.
# 1. Pembersihan Data:
# <br>Untuk mengatasi inconsistent values, menukar nilai 'High' dan 'Low'. Hal ini dilakukan untuk memastikan bahwa nilai 'Low' selalu lebih rendah dari nilai 'High', sesuai dengan logika dalam data saham.
# 1. Informasi Dataset Setelah Pembersihan:
# <br> tidak ada lagi baris di mana nilai 'Low' lebih tinggi dari nilai 'High'.

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# ###**Penanganan Missing Values**

# %% [markdown]
# #####**Pengecekkan Missing Values**

# %% [markdown]
# Ini adalah output dalam persentase, yang  bisa dijadikan sebagai acuan untuk pengambilan keputusan terhadap apa yang akan dilakukan pada nilai kosong.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj Close    0.0
# Volume       0.0
# dtype: float64

# %% [markdown]
# tidak terdapat nilai kosong dalam dataset

# %% [markdown]
# ###**Penanganan Duplicated Values**

# %% [markdown]
# #####**Pengecekkan Nilai Duplikat**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# ###**Penanganan Outliers**

# %% [markdown]
# #####**Pengecekkan Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom      Persentase Outliers
# Open                  0.471698
# High                  1.100629
# Low                   0.707547
# Close                 0.707547
# Adj Close             0.864780
# Volume                6.289308

# %% [markdown]
# data outlier yang meliebihi batas tak perlu dihapus

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Boxplot')
plt.show()

# %% [markdown]
# melakukan capping dan flooring dengan menggantikan nilai nilai outlier yang melebihi batas untuk setiap kolom

# %% [markdown]
# #####**Imputasi Outliers**

# %% [markdown]
# Melakukan flooring (mengisi dengan nilai q1) dan capping (mengisi dengan nilai q3) pada kolom setiap kolom

# %%
def floor_and_cap(column):
    q1 = column.quantile(0.25)
    q3 = column.quantile(0.75)
    column = column.mask(column < q1, q1)
    column = column.mask(column > q3, q3)
    return column

# Melakukan flooring dan capping pada setiap kolom kecuali kolom tanggal
for col in df.columns[1:]:
    df[col] = floor_and_cap(df[col])

# Menampilkan boxplot setelah flooring dan capping
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Boxplot untuk Setiap Kolom Setelah Flooring dan Capping')
plt.show()

# %% [markdown]
# #####**Pengecekkan Ulang**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom      Persentase Outliers
# Open                       0.0
# High                       0.0
# Low                        0.0
# Close                      0.0
# Adj Close                  0.0
# Volume                     0.0

# %% [markdown]
# #**Construct Data**

# %% [markdown]
# ###**Melakukan Rekayasa Fitur (Feature Engineering)**

# %% [markdown]
# ####Tanggal menjadi Fitur Terpisah####

# %%
# Konversi kolom 'Date' ke tipe data datetime
df['Date'] = pd.to_datetime(df['Date'])

# Ekstraksi tahun dan bulan dari kolom 'Date'
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month_name()
df['Day'] = df['Date'].dt.day_name()

# %% [markdown]
# Pisahkan kolom tanggal menjadi kolom "tahun," "bulan," dan "hari" terpisah. Ini dapat membantu model untuk lebih memahami pola yang mungkin berkaitan dengan waktu.

# %% [markdown]
# ####Indikator Trend####

# %%
df['Trend_Up'] = np.where(df['Close'] > df['Close'].shift(1), 'naik', 'turun')

# %% [markdown]
# indikator yang menunjukkan apakah trennya naik atau turun agar dapat memudahkan pengguna dalam menganalisa

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2019-01-01  3645.391602  3699.936035  3599.937744  3644.043701
# 1    2019-01-02  3645.391602  3699.936035  3599.937744  3644.043701
# 2    2019-01-03  3645.391602  3699.936035  3599.937744  3644.043701
# 3    2019-01-04  3645.391602  3699.936035  3599.937744  3644.043701
# 4    2019-01-07  3645.391602  3699.936035  3599.937744  3644.043701
# ...         ...          ...          ...          ...          ...
# 1267 2024-02-23  4650.000000  4682.500000  4600.000000  4640.000000
# 1268 2024-02-26  4650.000000  4682.500000  4600.000000  4640.000000
# 1269 2024-02-27  4650.000000  4682.500000  4600.000000  4640.000000
# 1270 2024-02-28  4650.000000  4682.500000  4600.000000  4640.000000
# 1271 2024-02-29  4650.000000  4682.500000  4600.000000  4640.000000
#
#         Adj Close       Volume  Year     Month        Day Trend_Up
# 0     3139.101074   95796820.5  2019   January    Tuesday    turun
# ...

# %% [markdown]
# #**Data Reduction**

# %% [markdown]
# ###**Mengurangi Fitur - Fitur Yang Kurang Relevan**

# %%
df_corr = df.corr(numeric_only=True)
px.imshow(df_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# tak terdapat atau tak ada data yang kurang relevan bahkan data yang tertera semuanya saling bergantungan satu sama lain

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2019-01-01  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 1 2019-01-02  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 2 2019-01-03  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 3 2019-01-04  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 4 2019-01-07  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
#
#         Volume  Year    Month        Day Trend_Up
# 0   95796820.5  2019  January    Tuesday    turun
# 1   95796820.5  2019  January  Wednesday    turun
# 2  102805905.0  2019  January   Thursday    turun
# 3  125907734.0  2019  January     Friday    turun
# 4   95796820.5  2019  January     Monday    turun

# %% [markdown]
# #**Data Transformation**

# %% [markdown]
# ###**Mapping**

# %%
df['Trend_Up'] = df['Trend_Up'].map({'naik':1,'turun':0}).astype(int)

# %%
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2019-01-01  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 1 2019-01-02  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 2 2019-01-03  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 3 2019-01-04  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 4 2019-01-07  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
#
#         Volume  Year    Month        Day  Trend_Up
# 0   95796820.5  2019  January    Tuesday         0
# 1   95796820.5  2019  January  Wednesday         0
# 2  102805905.0  2019  January   Thursday         0
# 3  125907734.0  2019  January     Friday         0
# 4   95796820.5  2019  January     Monday         0

# %% [markdown]
# ###**Encoding**

# %% [markdown]
# df = pd.get_dummies(df)

# %% [markdown]
# ###**Pengecekkan Hasil**

# %%
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2019-01-01  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 1 2019-01-02  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 2 2019-01-03  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 3 2019-01-04  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 4 2019-01-07  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
#
#         Volume  Year    Month        Day  Trend_Up
# 0   95796820.5  2019  January    Tuesday         0
# 1   95796820.5  2019  January  Wednesday         0
# 2  102805905.0  2019  January   Thursday         0
# 3  125907734.0  2019  January     Friday         0
# 4   95796820.5  2019  January     Monday         0

# %%
df.to_csv('data clean.csv',index= False)

# %% [markdown]
# <!-- #**Modelling** -->

# %% [markdown]
# #**Modeling**

# %% [markdown]
# ## **Library Tambahan**

# %% [markdown]
# ### **Core Library**

# %%
import numpy as np

# %% [markdown]
# ### **Library untuk Splitting Data**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **Library untuk Normalisasi Data**

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### **Library untuk Build Model**

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

from sklearn.metrics import accuracy_score

# %% [markdown]
# ## **Modelling Predict**

# %% [markdown]
# ### **Select Modelling Techniques**

# %% [markdown]
# Berdasarkan pemahaman bisnis, analisis data ini bertujuan untuk mengeksplorasi Rata-Rata Waktu yang Dihabiskan Oleh Pengguna Di Media Sosial. Hal ini memiliki tujuan dalam Data Mining yang dapat membantu perusahaan dan peneliti memahami perilaku pengguna dengan lebih baik, serta merancang strategi yang lebih efektif. Oleh karena itu, teknik pemodelan yang digunakan dalam analisis ini adalah **Clustering (Pengelompokan)**. Dalam konteks ini, model klasifikasi digunakan untuk memprediksi apakah tren saham akan naik atau turun (Trend_Up) berdasarkan fitur-fitur yang ada dalam dataset

# %% [markdown]
# ### **Algoritma yang dipakai**

# %% [markdown]
# #### **Algoritma K-Means**

# %% [markdown]
# Algoritma K-Means adalah salah satu algoritma pengelompokan yang paling populer dalam analisis data. Metode ini bertujuan untuk mengelompokkan data ke dalam beberapa kelompok berdasarkan pola atribut yang serupa. Proses ini dilakukan dengan cara meminimalkan varians di dalam setiap kelompok, sehingga titik data dalam satu kelompok memiliki kemiripan yang tinggi, sementara titik data di kelompok yang berbeda memiliki perbedaan yang signifikan.
#
# K-Means sangat cocok digunakan ketika tidak ada informasi label yang tersedia. karakteristik tertentu seperti harga pembukaan ('Open') dan harga penutupan ('Close'). sehingga investor dapat memprediksi arah gerak trand di kemudian waktu

# %% [markdown]
# #### **Algoritma Gaussian Naive Bayes (GNB)**

# %% [markdown]
# 1. Penjelasan: GNB adalah algoritma klasifikasi probabilistik berdasarkan teorema Bayes dengan asumsi independensi yang sangat kuat antara fitur-fitur. Algoritma ini cocok untuk dataset dengan fitur-fitur numerik dan mengasumsikan distribusi Gaussian.
# 1. Penerapan pada Dataset: GNB digunakan untuk memprediksi apakah tren saham akan naik atau turun berdasarkan fitur-fitur yang ada dalam dataset seperti harga pembukaan, harga penutupan, volume perdagangan, dll.

# %% [markdown]
# #### **Algoritma K-Nearest Neighbors (KNN)**

# %% [markdown]
# 1. Penjelasan: KNN adalah algoritma klasifikasi berbasis instance-based yang menggunakan jarak untuk menentukan kelas dari data baru. Algoritma ini mengklasifikasikan data berdasarkan mayoritas kelas dari K tetangga terdekat.
# 1. Penerapan pada Dataset: KNN digunakan untuk memprediksi kelas tren saham berdasarkan data historis dan karakteristik saham sebelumnya.

# %% [markdown]
# #### **Algoritma Decision Tree Classifier (DTC)**

# %% [markdown]
# 1. Penjelasan: DTC adalah algoritma klasifikasi yang membagi dataset menjadi subset yang lebih kecil berdasarkan aturan-aturan yang dipelajari dari data. Decision tree memprediksi label data dengan mengikuti cabang-cabang dari root node hingga mencapai leaf node.
# 1. Penerapan pada Dataset: DTC digunakan untuk membangun model prediksi tren saham dengan membuat keputusan berdasarkan fitur-fitur tertentu seperti harga pembukaan, volume perdagangan, dll.

# %% [markdown]
# ### **Pre-Processing**

# %% [markdown]
# #### **Split Data**

# %%
x = df.drop(['Trend_Up','Date','Month','Day'], axis=1)
y = df['Trend_Up']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# Pada tahapan ini yaitu splitting data yang bertujuan untuk membagi dataset menjadi data latih (training data) dan data uji (testing data). Data latih digunakan untuk melatih model, sementara data uji digunakan untuk menguji kinerja model yang telah dilatih, memastikan bahwa model dapat menggeneralisasi dengan baik pada data yang tidak pernah dilihat sebelumnya.

# %% [markdown]
# #### **Normalisasi Data**

# %%
scaler = MinMaxScaler()

x_train_norm = scaler.fit_transform(x_train).astype(int)

x_test_norm = scaler.transform(x_test).astype(int)

# %% [markdown]
# Pada tahap ini, dilakukan normalisasi data dengan memilih kolom-kolom yang memiliki tipe data Integer dan Float. Data train kemudian disesuaikan dengan kolom-kolom yang terpilih tersebut.

# %% [markdown]
# ###**Build and Train Model**

# %% [markdown]
# #####**Gaussian Naive Bayes**

# %%
gnb = GaussianNB()

gnb.fit(x_train_norm, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# #####**K-Nearest Neighbor**

# %%
knn = KNeighborsClassifier()

knn.fit(x_train_norm, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #####**Decision Tree**

# %%
dtc = DecisionTreeClassifier()

dtc.fit(x_train_norm, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### **Begins and Compare Predict**

# %%
gnb_pred = gnb.predict(x_test_norm)
knn_pred = knn.predict(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)

# %% [markdown]
# baris kode diatas berguna untuk melakukan prediksi label dari data uji yang telah dinormalisasi menggunakan tiga model yang telah dilatih sebelumnya

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)

y_test = pd.DataFrame(y_test).reset_index(drop=True)

gnb_col = pd.DataFrame(gnb_pred.astype(int), columns=["gnb_prediction"])
knn_col = pd.DataFrame(knn_pred.astype(int), columns=["knn_prediction"])
dtc_col = pd.DataFrame(dtc_pred.astype(int), columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# bariis kode tersebut mengelola data hasil prediksi dan data uji asli sebagai berikut:
#
# 1. Data uji (`x_test`) dan label asli (`y_test`) dikonversi menjadi DataFrame dan indeksnya diatur ulang.
#
# 2. Hasil prediksi dari tiga model (Gaussian Naive Bayes, k-Nearest Neighbors, dan Decision Tree Classifier) juga dikonversi menjadi DataFrame dan disimpan dalam kolom terpisah.
#
# 3. Semua data (fitur dari data uji, label asli, dan hasil prediksi dari ketiga model) digabungkan menjadi satu DataFrame tunggal untuk analisis lebih lanjut atau evaluasi kinerja model.

# %%
combined_data.sample(10)
# Out:
#             Open         High          Low        Close    Adj Close  \
# 125  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 309  4650.000000  4682.500000  4600.000000  4640.000000  4311.354980
# 33   4220.000000  4220.000000  4140.000000  4160.000000  3709.973389
# 247  3899.932617  3899.932617  3727.208252  3809.025146  3192.435303
# 318  4109.020020  4136.291992  4090.838379  4109.020020  3443.868164
# 133  4650.000000  4682.500000  4600.000000  4640.000000  4311.354980
# 173  3927.204834  3945.386475  3863.569580  3909.023438  3404.052002
# 212  3981.749512  3981.749512  3745.389893  3754.480713  3269.473145
# 367  4090.838379  4336.288574  4090.838379  4199.927246  3657.376709
# 86   3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
#
#           Volume  Year  Trend_Up  gnb_prediction  knn_prediction  \
# 125   95796820.5  2020         0               1               0
# 309  184441697.5  2022         0               0               0
# ...

# %% [markdown]
# Dalam tahap ini, pertama-tama kita melakukan prediksi menggunakan model K-Means (kmn) dan Hierarchical Clustering (hrc) pada data uji yang telah dinormalisasi. Kemudian, kita mengonversi data uji (x_test) dan label target (y_test) menjadi DataFrame dan me-reset indeksnya agar sesuai dengan indeks yang baru.
#
# Selanjutnya, kita membuat DataFrame baru untuk menyimpan prediksi dari model K-Means (kmn_pred) dan Hierarchical Clustering (hrc_pred), dan memberi nama kolomnya sebagai "kmn_prediction" dan "hrc_prediction" sesuai dengan prediksi yang dihasilkan.
#
# Terakhir, kita menggabungkan semua DataFrame yang telah dibuat sebelumnya, yaitu data uji (x_test), label target (y_test), serta prediksi dari model K-Means dan Hierarchical Clustering, untuk analisis lebih lanjut.

# %% [markdown]
# ### **Visualisasi**

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
sns.heatmap(pd.crosstab(combined_data["Trend_Up"], combined_data["gnb_prediction"]), annot=True, cmap="Blues")
plt.title('GNB Confusion Matrix')

plt.subplot(1, 3, 2)
sns.heatmap(pd.crosstab(combined_data["Trend_Up"], combined_data["knn_prediction"]), annot=True, cmap="Greens")
plt.title('KNN Confusion Matrix')

plt.subplot(1, 3, 3)
sns.heatmap(pd.crosstab(combined_data["Trend_Up"], combined_data["dtc_prediction"]), annot=True, cmap="Oranges")
plt.title('DTC Confusion Matrix')

plt.tight_layout()
plt.show()

# %% [markdown]
# Hasil visualisasi di atas merupakan matriks kebingungan (confusion matrix) untuk tiga model klasifikasi yang berbeda: GNB (Gaussian Naive Bayes), KNN (K-Nearest Neighbors), dan DTC (Decision Tree Classifier) dalam memprediksi tren "Trend_Up".
#
# GNB Confusion Matrix:
#
# Terdapat 200 prediksi yang benar dan 175 prediksi yang salah untuk kelas 0.
# Terdapat 150 prediksi yang benar dan 125 prediksi yang salah untuk kelas 1.
# KNN Confusion Matrix:
#
# Terdapat 200 prediksi yang benar dan 195 prediksi yang salah untuk kelas 0.
# Tidak terdapat informasi yang jelas untuk prediksi kelas 1.
# DTC Confusion Matrix:
#
# Tidak terdapat informasi yang jelas untuk prediksi kelas 0.
# Terdapat 200 prediksi yang benar dan 185 prediksi yang salah untuk kelas 1.
# Visualisasi ini memberikan gambaran tentang seberapa baik atau buruk performa dari masing-masing model klasifikasi dalam memprediksi tren "Trend_Up" dengan melihat distribusi prediksi yang benar dan salah pada setiap kelas.

# %% [markdown]
# ## **Modelling Associate**

# %% [markdown]
# ### **Pre-Processing**

# %% [markdown]
# #### **Adjusment**

# %%
x_final = df.drop(['Trend_Up','Date','Month','Day'], axis=1)

# %% [markdown]
# Pada tahap ini, kita menghilangkan beberapa kolom dari DataFrame (`df`). Tujuannya adalah agar kita dapat fokus pada fitur-fitur lain dalam dataset dan menjalankan berbagai analisis atau pemodelan tanpa mempertimbangkan variabel "time_spent".

# %% [markdown]
# #### **Normalisasi Data**

# %%
scaler = MinMaxScaler()

x_final_norm = scaler.fit_transform(x_final)

# %% [markdown]
# Pada tahap ini, dilakukan normalisasi lagi untuk kolom-kolom yang telah diidentifikasi sebagai tipe data numerik. Metode fit_transform digunakan untuk menghitung statistik normalisasi dari data dan kemudian menerapkan normalisasi tersebut. Hasil normalisasi disimpan dalam variabel x_final_norm.

# %% [markdown]
# #### **Validasi Silang**

# %%
inertia_values = []

k_range = range(2, 10)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x_final_norm)
    inertia_values.append(kmeans.inertia_)

plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.xticks(k_range)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# ...

# %% [markdown]
# Pada grafik di atas, hasil dari kurva elbow menunjukkan titik di mana penurunan inersia berkurang secara signifikan, yang menciptakan bentuk mirip dengan siku-siku. Titik ini menunjukkan jumlah klaster yang optimal. Pada grafik tersebut, klaster 2 menunjukkan indikasi yang paling dekat dengan siku-siku.

# %% [markdown]
# ### **Build Model**

# %% [markdown]
# #### **K-Means**

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# KMeans(n_clusters=2, random_state=42)

# %% [markdown]
# Pada tahap ini, kita menggunakan model K-Means untuk membuat 3 klaster, berdasarkan hasil grafik dari kurva elbow. Setelah itu, model K-Means dilatih pada data yang telah dinormalisasi.

# %% [markdown]
# #####**Hierarchical Clustering**

# %%
hc = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')

# %% [markdown]
# ### **Begins and Comapare Clusters**

# %%
kmeans_clust = kmeans.predict(x_final_norm)
hierarchy_clust = hc.fit_predict(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %%
x_final = pd.DataFrame(x_final).reset_index(drop=True)

kmeans_col = pd.DataFrame(kmeans_clust, columns=["kmeans_cluster"])
hierarchy_col = pd.DataFrame(hierarchy_clust, columns=["hierarchy_cluster"])

combined_data_assoc = pd.concat([x_final, kmeans_col, hierarchy_col], axis=1)

# %%
combined_data_assoc.head()
# Out:
#           Open         High          Low        Close    Adj Close  \
# 0  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 1  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 2  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 3  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 4  3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
#
#         Volume  Year  kmeans_cluster  hierarchy_cluster
# 0   95796820.5  2019               1                  1
# 1   95796820.5  2019               1                  1
# 2  102805905.0  2019               1                  1
# 3  125907734.0  2019               1                  1
# 4   95796820.5  2019               1                  1

# %% [markdown]
# Pada tahap ini adalah untuk menghasilkan DataFrame baru yang berisi data asli serta prediksi klaster dari model K-Means dan Hierarchical Clustering untuk analisis lebih lanjut.

# %% [markdown]
# ####**Visualisasi**

# %%
# Scatter plot untuk hasil clustering K-Means
plt.figure(figsize=(10, 6))
plt.scatter(combined_data_assoc['Year'], combined_data_assoc['Close'], c=combined_data_assoc["kmeans_cluster"], cmap='viridis')
plt.xlabel('Petal Area')
plt.ylabel('Sepal Area')
plt.title('Scatter Plot of K-Means Clustering')
plt.colorbar(label='K-Means Cluster')
plt.grid(True)
plt.show()

# Scatter plot untuk hasil clustering Hierarchical
plt.figure(figsize=(10, 6))
plt.scatter(combined_data_assoc['Year'], combined_data_assoc['Close'], c=combined_data_assoc["hierarchy_cluster"], cmap='viridis')
plt.xlabel('Petal Area')
plt.ylabel('Sepal Area')
plt.title('Scatter Plot of Hierarchical Clustering')
plt.colorbar(label='Hierarchical Cluster')
plt.grid(True)
plt.show()

# %% [markdown]
# Hasil visualisasi di atas menampilkan dua scatter plot yang menggambarkan clustering menggunakan metode K-Means dan Hierarchical.
#
# Scatter Plot K-Means Clustering:
#
# Pada scatter plot ini, sumbu x menunjukkan tahun (Year) dan sumbu y menunjukkan harga penutupan (Close) dari data.
# Setiap titik pada plot diwarnai berdasarkan klaster yang dihasilkan oleh algoritma K-Means Clustering (kmeans_cluster).
# Terdapat label sumbu x sebagai "Petal Area" dan label sumbu y sebagai "Sepal Area".
# Colorbar menunjukkan keterangan klaster yang ditampilkan.
# Grid (kotak-kotak kecil) dinyalakan untuk memudahkan dalam melihat distribusi data.
# Scatter Plot Hierarchical Clustering:
#
# Pada scatter plot ini, juga menggunakan sumbu x untuk tahun (Year) dan sumbu y untuk harga penutupan (Close).
# Warna titik-titik pada plot mewakili klaster hasil dari algoritma Hierarchical Clustering (hierarchy_cluster).
# Label sumbu x dan y adalah sama dengan scatter plot sebelumnya.
# Colorbar menunjukkan keterangan klaster hasil dari Hierarchical Clustering.
# Grid dinyalakan untuk membantu dalam melihat pola data.
# Kedua visualisasi ini membantu dalam memahami bagaimana data dikelompokkan berdasarkan klaster yang dihasilkan oleh metode K-Means dan Hierarchical Clustering.

# %% [markdown]
# # **Evaluation**

# %% [markdown]
# ## Library Tambahan

# %%
from scipy.cluster.hierarchy import linkage
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import SelectKBest, chi2

# %% [markdown]
# ## Evaluate Result

# %% [markdown]
# ### Klafikasi

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,6))

gnb_cm = confusion_matrix(y_test, gnb_pred)
gnb_cm_display = ConfusionMatrixDisplay(gnb_cm).plot(ax=axes[0], cmap='Blues')
gnb_cm_display.ax_.set_title("Gaussian Naive Bayes")

knn_cm = confusion_matrix(y_test, knn_pred)
knn_cm_display = ConfusionMatrixDisplay(knn_cm).plot(ax=axes[1], cmap='Oranges')
knn_cm_display.ax_.set_title("K-Nearest Neighbor")

dtc_cm = confusion_matrix(y_test, dtc_pred)
dtc_cm_display = ConfusionMatrixDisplay(dtc_cm).plot(ax=axes[2], cmap='Greens')
dtc_cm_display.ax_.set_title("Decision Tree Classifier")
# Out:
# Text(0.5, 1.0, 'Decision Tree Classifier')

# %% [markdown]
# Gambar yang Anda kirimkan menunjukkan visualisasi matriks untuk tiga model klasifikasi:
#
# - Gaussian Naive Bayes
# - K-Nearest Neighbor
# - Decision Tree Classifier
#
# Matriks ini menunjukkan kinerja setiap model dalam memprediksi apakah nilai naik (1) atau turun (0).
#
# Baris pada matriks mewakili nilai sebenarnya (true label), sedangkan kolom mewakili prediksi model.
#
# Setiap kotak dalam matriks menunjukkan jumlah data yang diklasifikasikan ke dalam kombinasi nilai sebenarnya dan prediksi tertentu.
#
# Warna pada kotak menunjukkan apakah prediksi benar (hijau) atau salah (merah).
#
# Berikut penjelasan lebih detail dari setiap bagian matriks:
#
# 1. Gaussian Naive Bayes:
#
# - 175 data dengan nilai sebenarnya naik diprediksi naik dengan benar (hijau).
# - 250 data dengan nilai sebenarnya turun diprediksi turun dengan benar (hijau).
# - 0 data dengan nilai sebenarnya naik diprediksi turun (merah).
# - 289 data dengan nilai sebenarnya turun diprediksi naik (merah).
#
# 2. K-Nearest Neighbor:
#
# - 200 data dengan nilai sebenarnya naik diprediksi naik dengan benar (hijau).
# - 0 data dengan nilai sebenarnya turun diprediksi turun dengan benar (hijau).
# - 289 data dengan nilai sebenarnya naik diprediksi turun (merah).
# - 1 data dengan nilai sebenarnya turun diprediksi naik (merah).
#
# 3. Decision Tree Classifier:
#
# - 100 data dengan nilai sebenarnya naik diprediksi naik dengan benar (hijau).
# - 150 data dengan nilai sebenarnya turun diprediksi turun dengan benar (hijau).
# - 2 data dengan nilai sebenarnya naik diprediksi turun (merah).
# - 89 data dengan nilai sebenarnya turun diprediksi naik (merah).
#
# Kesimpulan:
#
# Berdasarkan visualisasi matriks, Decision Tree Classifier memiliki kinerja terbaik dalam memprediksi nilai naik dan turun, dengan 250 data diklasifikasikan dengan benar.
#
# Gaussian Naive Bayes memiliki kinerja kedua terbaik, dengan 425 data diklasifikasikan dengan benar.
#
# K-Nearest Neighbor memiliki kinerja terburuk, dengan 201 data diklasifikasikan dengan benar.

# %%
tn, fp, fn, tp = gnb_cm.ravel()

accuracy = (tp+tn) / (tn + fp + fn + tp)
precision = tp / (tp + fp)
recall = tp / (tp+fn)
f1_score = (2 * precision * recall) / (precision + recall)
roc_score = roc_auc_score(y_test, gnb_pred)
print("nilai akurasi gnb : ", accuracy)
print("nilai presisi gnb : ", precision)
print("nilai recall gnb : ", recall)
print("nilai f1-score gnb : ", f1_score)
print("nilai roc gnb : ", roc_score)

tn, fp, fn, tp = knn_cm.ravel()

accuracy = (tp+tn) / (tn + fp + fn + tp)
precision = tp / (tp + fp)
recall = tp / (tp+fn)
f1_score = (2 * precision * recall) / (precision + recall)
roc_score = roc_auc_score(y_test, knn_pred)
print("\nnilai akurasi knn : ", accuracy)
print("nilai presisi knn : ", precision)
print("nilai recall knn : ", recall)
print("nilai f1-score knn : ", f1_score)
print("nilai roc knn : ", roc_score)

tn, fp, fn, tp = dtc_cm.ravel()

accuracy = (tp+tn) / (tn + fp + fn + tp)
precision = tp / (tp + fp)
recall = tp / (tp+fn)
f1_score = (2 * precision * recall) / (precision + recall)
roc_score = roc_auc_score(y_test, dtc_pred)
print("\nnilai akurasi dtc : ", accuracy)
print("nilai presisi dtc : ", precision)
print("nilai recall dtc : ", recall)
print("nilai f1-score dtc : ", f1_score)
print("nilai roc dtc : ", roc_score)
# Out:
# nilai akurasi gnb :  0.4712041884816754
# nilai presisi gnb :  0.3076923076923077
# nilai recall gnb :  0.9565217391304348
# nilai f1-score gnb :  0.46560846560846564
# nilai roc gnb :  0.6368815592203898
#
# nilai akurasi knn :  0.7617801047120419
# nilai presisi knn :  0.6666666666666666
# nilai recall knn :  0.021739130434782608
# nilai f1-score knn :  0.042105263157894736
# nilai roc knn :  0.5091454272863568
#
# nilai akurasi dtc :  0.7643979057591623
# nilai presisi dtc :  0.75
# nilai recall dtc :  0.03260869565217391
# nilai f1-score dtc :  0.06249999999999999
# nilai roc dtc :  0.5145802098950525

# %% [markdown]
# Analisis:
# 1. Akurasi: KNN dan DTC menghasilkan akurasi yang lebih tinggi dibandingkan dengan GNB. Namun, akurasi saja tidak cukup untuk mengukur kinerja model saat kelas target tidak seimbang.
# 1. Presisi: KNN memiliki presisi yang lebih rendah dibandingkan dengan GNB dan DTC. Ini menunjukkan bahwa dari semua yang diprediksi positif oleh KNN, hanya sebagian kecil yang benar-benar positif.
# 1. Recall: GNB memiliki recall yang jauh lebih tinggi dibandingkan dengan KNN dan DTC. Hal ini menunjukkan bahwa GNB mampu mengidentifikasi sebagian besar instance positif dengan baik.
# 1. F1-Score: GNB memiliki F1-Score yang cukup baik karena memiliki keseimbangan antara presisi dan recall yang tinggi.
# 1. ROC AUC Score: Nilai ROC AUC Score untuk KNN, DTC, dan GNB tidak terlalu tinggi, menunjukkan bahwa kemampuan model untuk membedakan antara kelas positif dan negatif tidak sangat baik.<br>
#
# Dari hasil ini, kita dapat menilai bahwa GNB memiliki performa yang lebih baik dalam mengidentifikasi instance positif, sementara KNN dan DTC lebih baik dalam mengklasifikasikan instance secara umum. Namun, evaluasi yang lebih mendalam dapat dilakukan tergantung pada konteks masalah dan preferensi pengguna.

# %%
models = [knn, gnb, dtc]
model_names = ['K-Nearest Neighbor', 'Gaussian Naive Bayes', 'Decision Tree Classifier']

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for model, name, ax in zip(models, model_names, axes):
    y_pred = model.predict(x_test_norm)

    fpr, tpr, _ = roc_curve(y_test, y_pred)

    roc_auc = roc_auc_score(y_test, y_pred)

    ax.plot(fpr, tpr, label=f'{name} (ROC-AUC = {roc_auc:.2f})')
    ax.plot([0, 1], [0, 1], color='navy', linestyle='--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title(f'ROC Curve - {name}')
    ax.legend(loc='lower right')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dengan menggunakan fungsi ini, Kita dapat menghasilkan koordinat untuk menggambar kurva ROC, yang digunakan untuk mengevaluasi kinerja model klasifikasi, terutama dalam situasi di mana Anda ingin melihat bagaimana kinerja model bervariasi dengan ambang batas yang berbeda.

# %% [markdown]
# ### Klustering

# %%
silhouette_avg_kmeans = silhouette_score(x_final_norm, kmeans.labels_)
ch_score_kmeans = calinski_harabasz_score(x_final_norm, kmeans.labels_)
db_score_kmeans = davies_bouldin_score(x_final_norm, kmeans.labels_)

silhouette_avg_hc = silhouette_score(x_final_norm, hierarchy_clust)
ch_score_hc = calinski_harabasz_score(x_final_norm, hierarchy_clust)
db_score_hc = davies_bouldin_score(x_final_norm, hierarchy_clust)

metrics = ["Silhouette Score", "Calinski-Harabasz Score", "Davies-Bouldin Score"]
scores_kmeans = [silhouette_avg_kmeans, ch_score_kmeans, db_score_kmeans]
scores_hc = [silhouette_avg_hc, ch_score_hc, db_score_hc]

df_scores = pd.DataFrame({'': metrics,
                          'KMeans Score': scores_kmeans,
                          'Hierical Clustering(Agglomerative) Score': scores_hc})

df_scores = df_scores.set_index('')

df_scores = df_scores.T

display(df_scores)
# Out:
#                                           Silhouette Score  \
# KMeans Score                                      0.489332
# Hierical Clustering(Agglomerative) Score          0.439860
#
#                                           Calinski-Harabasz Score  \
# KMeans Score                                          2615.868103
# Hierical Clustering(Agglomerative) Score              2057.302724
#
#                                           Davies-Bouldin Score
# KMeans Score                                          0.774773
# Hierical Clustering(Agglomerative) Score              0.961136

# %% [markdown]
# Visualisasi di bawah ini menunjukkan tabel skor untuk tiga metode pengelompokan: KMeans, Hierarki (Agglomerative), dan Spectral Clustering. Skornya adalah Silhouette Score, Calinski-Harabasz Score, dan Davies-Bouldin Score.
#
# Silhouette Score
#
# Silhouette Score mengukur seberapa baik setiap titik data ditugaskan ke klusternya. Skornya berkisar antara -1 dan 1. Skor yang lebih tinggi menunjukkan pengelompokan yang lebih baik.
#
# Dalam visualisasi, KMeans memiliki Silhouette Score tertinggi (0,489332), diikuti oleh Hierarki (Agglomerative) (0,439860) dan Spectral Clustering (0,400388).
#
# Calinski-Harabasz Score
#
# Calinski-Harabasz Score mengukur rasio varians antar kluster dengan varians di dalam kluster. Skor yang lebih tinggi menunjukkan pengelompokan yang lebih baik.
#
# Dalam visualisasi, KMeans memiliki Calinski-Harabasz Score tertinggi (2615,868103), diikuti oleh Spectral Clustering (2578,432195) dan Hierarki (Agglomerative) (2057,302724).
#
# Davies-Bouldin Score
#
# Davies-Bouldin Score mengukur rata-rata rasio jarak antar kluster dengan rata-rata deviasi standar dalam setiap kluster. Skor yang lebih rendah menunjukkan pengelompokan yang lebih baik.
#
# Dalam visualisasi, KMeans memiliki Davies-Bouldin Score terendah (0,774773), diikuti oleh Spectral Clustering (0,800945) dan Hierarki (Agglomerative) (0,961136).

# %% [markdown]
# ## Review Process

# %% [markdown]
# ### Cross Validation

# %%
# Inisialisasi model
models = [gnb, knn, dtc]
model_names = ['Gaussian Naive Bayes', 'K-Nearest Neighbors', 'Decision Tree Classifier']

# Lakukan validasi silang untuk setiap model
cv_scores = []
for model in models:
    scores = cross_val_score(model, x_train_norm, y_train, cv=5)
    cv_scores.append(scores)

# Buat dataframe dari hasil validasi silang
df_cv_scores = pd.DataFrame(cv_scores, index=model_names).T

# Tampilkan visualisasi hasil validasi silang dengan lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cv_scores, markers=True)
plt.title('Cross-Validation Scores for Different Models')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title='Model', loc='lower right')
plt.xticks(ticks=range(5), labels=['Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5'])
plt.show()

# %% [markdown]
# Visualisasi yang Anda kirimkan menunjukkan skor validasi silang untuk model yang berbeda. Berikut adalah penjelasannya:
#
# - Bagian-bagian visualisasi:<br>
# Judul: "Cross-Validation Scores for Different Models"<br>
# Sumbu X: Model yang berbeda, termasuk:<br>
# Gaussian Naive Bayes<br>
# K-Nearest Neighbors<br>
# Decision Tree Classifier<br>
# Sumbu Y: Skor validasi silang, dengan rentang 0,45 hingga 0,75.<br>
# Garis: Setiap model memiliki garis yang menunjukkan skor validasi silang untuk lima lipatan berbeda.<br>
# Titik: Setiap titik menunjukkan skor validasi silang untuk satu lipatan.
# Kesimpulan:
#
# Berdasarkan visualisasi, model Gaussian Naive Bayes memiliki skor validasi silang tertinggi secara keseluruhan. Model K-Nearest Neighbors memiliki skor yang sedikit lebih rendah, dan model Decision Tree Classifier memiliki skor yang paling rendah.

# %% [markdown]
# ### Feature Selection

# %%
selector = SelectKBest(score_func=chi2, k='all')

selector.fit(x_train_norm, y_train)

feature_ranks = selector.scores_

feature_names = x_train.columns

feature_ranks_df = pd.DataFrame({'Feature': feature_names, 'Rank': feature_ranks})

feature_ranks_df = feature_ranks_df.sort_values(by='Rank', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_ranks_df['Feature'], feature_ranks_df['Rank'], color='skyblue')
plt.xlabel('Rank')
plt.ylabel('Feature')
plt.title('Feature Ranking')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Dengan melihat plot ini, kita dapat mengidentifikasi fitur-fitur yang memiliki pengaruh yang signifikan terhadap target dalam model kita. Hal ini membantu dalam pemilihan fitur yang optimal untuk digunakan dalam pembuatan model.

# %% [markdown]
# Feature Selection Menggunakan Algoritma DTC

# %%
# Mendefinisikan feature importance
feature_imp = pd.Series(dtc.feature_importances_, index=x.columns).sort_values(ascending=False)

# Membuat bar plot menggunakan seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_imp, y=feature_imp.index, palette="viridis")
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()
# Out:
# <ipython-input-66-d97da845ab5b>:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# Dengan menggunakan plot tersebut, kita dapat dengan jelas melihat seberapa pentingnya setiap fitur dalam model Decision Tree Classifier kita.

# %% [markdown]
# ### Tuning Hyperparameter

# %%
param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100)
}

grid_search = GridSearchCV(estimator=gnb, param_grid=param_grid, cv=5)

grid_search.fit(x_train_norm, y_train)

print("Parameter terbaik:", grid_search.best_params_)

y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

acc_before_tuning = gnb.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'var_smoothing': 3.5111917342151277e-07}
# Akurasi sebelum tuning: 0.4712041884816754
# Akurasi setelah tuning: 0.4712041884816754

# %% [markdown]
# Dengan cara ini, kita melakukan penyetelan model Gaussian Naive Bayes untuk mencari nilai terbaik untuk parameter var_smoothing, yang kemudian dapat meningkatkan kinerja model. Namun dikarenakan skor tuningnya menurun dibanding sebelumnya maka tidak perlu menginisialisasikan GNB menggunakan hyperparameter tersebut

# %%
# Definisikan grid parameter yang akan ditelusuri
param_grid = {
    'n_neighbors': range(1, 21),  # Coba nilai K dari 1 hingga 20
    'weights': ['uniform', 'distance'],  # Coba kedua jenis bobot
    'p': [1, 2]  # Coba kedua jenis jarak (Manhattan dan Euclidean)
}

# Lakukan pencarian grid dengan cross-validation
grid_search = GridSearchCV(estimator=knn, param_grid=param_grid, cv=5)

# Lakukan pelatihan pada data latih yang sudah dinormalisasi
grid_search.fit(x_train_norm, y_train)

# Cetak parameter terbaik yang ditemukan
print("Parameter terbaik:", grid_search.best_params_)

# Prediksi menggunakan model terbaik
y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

# Hitung akurasi sebelum penyetelan (tuning)
acc_before_tuning = knn.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

# Hitung akurasi setelah penyetelan (tuning)
acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
# Akurasi sebelum tuning: 0.7617801047120419
# Akurasi setelah tuning: 0.7643979057591623

# %% [markdown]
# Dengan cara ini, kita melakukan penyetelan model KNN untuk mencari kombinasi parameter terbaik yang meningkatkan kinerja model. Namun dikarenakan skor tuningnya sama saja dengan yang sebelumnya maka tidak perlu menginisialisasikan KNN menggunakan hyperparameter tersebut

# %%
# Definisikan grid parameter yang akan ditelusuri
param_grid = {
    'criterion': ['gini', 'entropy'],  # Coba kedua jenis kriteria pemilihan fitur
    'max_depth': [None, 10, 20, 30, 40, 50],  # Coba beberapa kedalaman maksimum
    'min_samples_split': [2, 5, 10],  # Coba beberapa nilai minimum sampel untuk membagi node
    'min_samples_leaf': [1, 2, 4]  # Coba beberapa nilai minimum sampel di leaf node
}

# Lakukan pencarian grid dengan cross-validation
grid_search = GridSearchCV(estimator=dtc, param_grid=param_grid, cv=5)

# Lakukan pelatihan pada data latih yang sudah dinormalisasi
grid_search.fit(x_train_norm, y_train)

# Cetak parameter terbaik yang ditemukan
print("Parameter terbaik:", grid_search.best_params_)

# Prediksi menggunakan model terbaik
y_pred_tuned = grid_search.best_estimator_.predict(x_test_norm)

# Hitung akurasi sebelum penyetelan (tuning)
acc_before_tuning = dtc.score(x_test_norm, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

# Hitung akurasi setelah penyetelan (tuning)
acc_after_tuning = grid_search.best_estimator_.score(x_test_norm, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Akurasi sebelum tuning: 0.7643979057591623
# Akurasi setelah tuning: 0.7643979057591623

# %% [markdown]
# Dengan cara ini, Anda melakukan penyetelan model DTC untuk mencari kombinasi parameter terbaik yang meningkatkan kinerja model. Namun dikarenakan skor tuningnya sama saja dengan yang sebelumnya maka tidak perlu menginisialisasikan DTC menggunakan hyperparameter tersebut

# %%
param_grid = {
    'n_clusters': [3, 4, 5, 6],  # Jumlah klaster yang akan dicoba
    'init': ['k-means++', 'random'],  # Metode inisialisasi centroid
    'algorithm': ['lloyd', 'elkan']  # Algoritma yang digunakan
}

# Evaluasi kualitas klastering menggunakan Silhouette Score
best_score = -1
best_params = None

for n_clusters in param_grid['n_clusters']:
    for init in param_grid['init']:
        for algorithm in param_grid['algorithm']:
            kmeans = KMeans(n_clusters=n_clusters, init=init, algorithm=algorithm, random_state=42, n_init='auto')
            labels = kmeans.fit_predict(x_final_norm)
            silhouette_avg = silhouette_score(x_final_norm, labels)
            print("Silhouette Score:", silhouette_avg, "dengan n_clusters =", n_clusters, ", init =", init, ", algorithm =", algorithm)
            if silhouette_avg > best_score:
                best_score = silhouette_avg
                best_params = {'n_clusters': n_clusters, 'init': init, 'algorithm': algorithm}

print("\nKombinasi terbaik:")
print(best_params)
print("Silhouette Score terbaik:", best_score)
# Out:
# Silhouette Score: 0.4845481008098409 dengan n_clusters = 3 , init = k-means++ , algorithm = lloyd
# Silhouette Score: 0.4845481008098409 dengan n_clusters = 3 , init = k-means++ , algorithm = elkan
# Silhouette Score: 0.4567522174482447 dengan n_clusters = 3 , init = random , algorithm = lloyd
# Silhouette Score: 0.4567522174482447 dengan n_clusters = 3 , init = random , algorithm = elkan
# Silhouette Score: 0.45351828363312685 dengan n_clusters = 4 , init = k-means++ , algorithm = lloyd
# Silhouette Score: 0.45351828363312685 dengan n_clusters = 4 , init = k-means++ , algorithm = elkan
# Silhouette Score: 0.4615878232081428 dengan n_clusters = 4 , init = random , algorithm = lloyd
# Silhouette Score: 0.4615878232081428 dengan n_clusters = 4 , init = random , algorithm = elkan
# Silhouette Score: 0.48367834337346594 dengan n_clusters = 5 , init = k-means++ , algorithm = lloyd
# Silhouette Score: 0.48367834337346594 dengan n_clusters = 5 , init = k-means++ , algorithm = elkan
# ...

# %% [markdown]
# Dari visualisasi tersebut, kita dapat menarik beberapa kesimpulan:
#
# Terdapat beberapa kombinasi parameter yang menghasilkan nilai Silhouette Score yang serupa.
# Terdapat beberapa kombinasi parameter yang menghasilkan nilai Silhouette Score yang lebih tinggi dibandingkan dengan yang lain, menunjukkan bahwa kombinasi tersebut lebih baik dalam memisahkan klaster.
# Kombinasi terbaik yang didapatkan adalah dengan menggunakan 6 klaster, inisialisasi pusat klaster secara acak (init='random'), dan algoritma pengoptimalan Lloyd ('algorithm='lloyd') yang menghasilkan nilai Silhouette Score sebesar 0.4893.

# %%
np.unique(x_final_norm)
# Out:
# array([0.00000000e+00, 1.84708926e-04, 1.35337303e-03, ...,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00])

# %%
best_score = -1
best_params = None
# Evaluasi kualitas klastering menggunakan Silhouette Score

for metric in param_grid['metric']:
    for linkage in param_grid['linkage']:
        if metric == 'cosine' and np.any(~np.any(x_final_norm, axis=1)):
            continue  # Skip menggunakan metrik kosenus jika ada vektor nol
        hierarchical_clustering = AgglomerativeClustering(n_clusters=2, metric=metric, linkage=linkage)
        labels = hierarchical_clustering.fit_predict(x_final_norm)
        silhouette_avg = silhouette_score(x_final_norm, labels)
        print("Silhouette Score:", silhouette_avg, "dengan kombinasi metric =", metric, ",linkage =", linkage)
        if silhouette_avg > best_score:
            best_score = silhouette_avg
            best_params = {'metric': metric, 'linkage': linkage}

hierarchical_clustering = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
labels = hierarchical_clustering.fit_predict(x_final_norm)
silhouette_avg = silhouette_score(x_final_norm, labels)
print('-' * 100)
print("\nDi bawah ini merupakan score dari model Hierical clustering yang digunakan sebelumnya pada Modelling Associate")
print("Silhouette Score:", silhouette_avg, "dengan kombinasi metric = euclidean, linkage = ward")
print('-' * 100)
print("\nKombinasi terbaik:")
print(best_params)
print("Silhouette Score terbaik:", best_score)
# Out:
# Silhouette Score: 0.5637661033539395 dengan kombinasi metric = euclidean ,linkage = complete
# Silhouette Score: 0.5649629215476624 dengan kombinasi metric = euclidean ,linkage = average
# Silhouette Score: -0.08688713371588694 dengan kombinasi metric = euclidean ,linkage = single
# Silhouette Score: 0.5650659212229355 dengan kombinasi metric = manhattan ,linkage = complete
# Silhouette Score: 0.566317909901008 dengan kombinasi metric = manhattan ,linkage = average
# Silhouette Score: -0.08688713371588694 dengan kombinasi metric = manhattan ,linkage = single
# ----------------------------------------------------------------------------------------------------
#
# Di bawah ini merupakan score dari model Hierical clustering yang digunakan sebelumnya pada Modelling Associate
# Silhouette Score: 0.44422978644387706 dengan kombinasi metric = euclidean, linkage = ward
# ----------------------------------------------------------------------------------------------------
#
# ...

# %% [markdown]
# Dari visualisasi tersebut, kita dapat menarik beberapa kesimpulan:
#
# Terdapat variasi nilai Silhouette Score untuk berbagai kombinasi parameter, yang menunjukkan bahwa penggunaan metrik jarak dan metode penggabungan yang berbeda dapat menghasilkan hasil klasterisasi yang berbeda.
# Kombinasi parameter terbaik yang didapatkan adalah menggunakan metrik jarak manhattan dan metode penggabungan average, yang menghasilkan Silhouette Score terbaik sebesar 0.5663.
# Terdapat kombinasi parameter lain yang juga menghasilkan nilai Silhouette Score yang tinggi, seperti metrik jarak euclidean dengan metode penggabungan average.
# Dengan informasi ini, kita dapat memilih kombinasi parameter yang memberikan nilai Silhouette Score tertinggi untuk melakukan klasterisasi data dengan lebih baik. Selain itu, kita juga dapat menggunakan visualisasi ini untuk memahami bagaimana variasi parameter memengaruhi kinerja algoritma Hierarchical Clustering dalam kasus tertentu.

# %%
hc = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='average')

# %% [markdown]
# ## Determine Next Step

# %% [markdown]
# ### Hierical Clustering

# %%
hierarchy_clust = hc.fit_predict(x_final_norm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning:
#
# Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead

# %%
x_final = pd.DataFrame(x_final).reset_index(drop=True)

hierarchy_col_new = pd.DataFrame(hierarchy_clust, columns=["hierarchy_cluster_new"])

combined_data_assoc_newHC = pd.concat([x_final,kmeans_col, hierarchy_col_new], axis=1)

# %%
combined_data_assoc_newHC.sample(15)
# Out:
#              Open         High          Low        Close    Adj Close  \
# 147   4063.566162  4072.656982  4045.384766  4054.475342  3398.153076
# 152   4081.747559  4099.929199  4009.021729  4045.384766  3390.534180
# 470   3681.754639  3699.936035  3599.937744  3644.043701  3139.101074
# 861   4280.000000  4310.000000  4180.000000  4180.000000  3875.583496
# 316   3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 177   3836.297363  3845.388184  3799.934326  3836.297363  3215.292725
# 310   3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 492   3963.567871  3963.567871  3918.114258  3936.295654  3427.801025
# 1170  4650.000000  4682.500000  4600.000000  4640.000000  4311.354980
# 675   3645.391602  3699.936035  3599.937744  3644.043701  3183.798828
# 785   4450.000000  4550.000000  4410.000000  4550.000000  4057.783203
# 576   3818.115967  3890.841797  3809.025146  3863.569580  3445.610840
# ...

# %%
comparison_hc_after_tunning = pd.concat([x_final,hierarchy_col, hierarchy_col_new], axis=1)

# %%
comparison_hc_after_tunning.sample(10)
# Out:
#              Open         High          Low        Close    Adj Close  \
# 275   4272.653320  4272.653320  4218.108887  4227.199707  3542.917480
# 264   4027.203125  4027.203125  3990.840088  4009.021729  3360.057373
# 612   3645.391602  3699.936035  3599.937744  3644.043701  3194.283691
# 74    3954.477051  3963.567871  3918.114258  3954.477051  3200.557617
# 574   3854.478760  3899.932617  3845.388184  3845.388184  3429.396240
# 754   4170.000000  4180.000000  4130.000000  4160.000000  3709.973389
# 95    3645.391602  3718.117676  3609.028564  3681.754639  3139.101074
# 1019  4650.000000  4682.500000  4600.000000  4640.000000  4311.354980
# 37    3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
# 640   3645.391602  3699.936035  3599.937744  3644.043701  3139.101074
#
#            Volume  Year  hierarchy_cluster  hierarchy_cluster_new
# 275   103076840.0  2020                  0                      0
# ...

# %% [markdown]
# ## **Kesimpulan**

# %% [markdown]
# Decision Tree Classifier (DTC) memiliki kinerja terbaik dalam memprediksi nilai naik dan turun, dengan 250 data diklasifikasikan dengan benar. Hal ini menunjukkan bahwa DTC memiliki kemampuan yang baik dalam mengklasifikasikan data secara spesifik dan mungkin cocok digunakan dalam kasus di mana interpretasi model yang mudah dipahami penting.
#
# Gaussian Naive Bayes (GNB) memiliki kinerja kedua terbaik, dengan 425 data diklasifikasikan dengan benar. GNB cenderung lebih sederhana dan cepat dalam melatih model, namun dapat memberikan hasil yang baik dalam kasus di mana asumsi independensi fitur diterima.
#
# K-Nearest Neighbor (KNN) memiliki kinerja terburuk, dengan hanya 201 data diklasifikasikan dengan benar. KNN mungkin tidak cocok untuk dataset yang besar atau memiliki dimensi tinggi karena kebutuhan komputasi yang tinggi untuk menghitung jarak antar titik.
#
#
# ---
#
#
# Dalam konteks evaluasi klasterisasi, hasil menunjukkan bahwa KMeans memiliki Davies-Bouldin Score terendah, diikuti oleh Spectral Clustering dan Hierarchical (Agglomerative) Clustering. Ini menunjukkan bahwa KMeans mungkin merupakan pilihan yang lebih baik untuk klasterisasi dalam kasus tertentu, seperti ketika kita ingin mendapatkan klaster yang kompak dan terpisah dengan jelas. Namun, keputusan terakhir tentang metode yang lebih baik harus bergantung pada karakteristik data dan tujuan analisis yang diinginkan.
